# %% [markdown]
# # RNN기반 분류기

# %%
# # 데이터 로딩
# from sklearn.datasets import fetch_20newsgroups

# categories = ['comp.graphics', 'sci.space', 'rec.sport.baseball']
# newsgroups = fetch_20newsgroups(subset='all', categories=categories)
# X = newsgroups.data
# y = newsgroups.target
# print(newsgroups.target_names)
# print(X[0])
# print(y[0])

# %%
import zipfile
import re
import numpy as np
from sklearn.utils import Bunch
from sklearn.utils import check_random_state

zip_path = "archive.zip"

categories = [
    "comp.graphics",
    "sci.space",
    "rec.sport.baseball"
]

data = []
target = []

with zipfile.ZipFile(zip_path, "r") as z:
    for label, name in enumerate(categories):
        filename = f"{name}.txt"

        text = z.read(filename).decode("latin1")

        # 각 문서는 보통 From: 으로 시작하므로 From: 기준으로 분리한다.
        docs = re.split(r"(?m)(?=^From: )", text)
        docs = [doc.strip() for doc in docs if doc.strip()]

        data.extend(docs)
        target.extend([label] * len(docs))

# fetch_20newsgroups()와 비슷하게 데이터를 섞는다.
rng = check_random_state(42)
indices = np.arange(len(data))
rng.shuffle(indices)

data = [data[i] for i in indices]
target = np.array([target[i] for i in indices])

newsgroups = Bunch(
    data=data,
    target=target,
    target_names=categories
)

X = newsgroups.data
y = newsgroups.target

print(newsgroups.target_names)
print(X[0])
print(y[0])
# Out:
# ['comp.graphics', 'sci.space', 'rec.sport.baseball']
# From: pyron@skndiv.dseg.ti.com (Dillon Pyron)
# Subject: Re: A WRENCH in the works?
#
#
# In article <25228@ksr.com>, jfw@ksr.com (John F. Woods) writes:
# >nanderso@Endor.sim.es.com (Norman Anderson) writes:
# >>jmcocker@eos.ncsu.edu (Mitch) writes:
# >>>effect that one of the SSRBs that was recovered after the
# >>>recent space shuttle launch was found to have a wrench of
# >>>some sort rattling around apparently inside the case.
# >>I heard a similar statement in our local news (UTAH) tonight. They referred
# >>to the tool as "...the PLIERS that took a ride into space...". They also
# >>said that a Thiokol (sp?) employee had reported missing a tool of some kind
# >>during assembly of one SRB.
#
# It was a test of the first reusable tool.
#
# >
# >I assume, then, that someone at Thiokol put on their "manager's hat" and said
# >that pissing off the customer by delaying shipment of the SRB to look inside
# >it was a bad idea, regardless of where that tool might have ended up.
# >
# >Why do I get the feeling that Thiokol "manager's hats" are shaped like cones?
#
# Pointy so they can find them or so they will stick into their pants better, and
# be closer to their brains?
# --
# Dillon Pyron                      | The opinions expressed are those of the
# TI/DSEG Lewisville VAX Support    | sender unless otherwise stated.
# (214)462-3556 (when I'm here)     |
# (214)492-4656 (when I'm home)     |Texans: Vote NO on Robin Hood.  We need
# pyron@skndiv.dseg.ti.com          |solutions, not gestures.
# PADI DM-54909                     |
#
#
# Newsgroup: sci.space
# Document_id: 60821
# 1

# %%
# 데이터전처리
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

vocab_size = 10000
max_len = 200

tokenizer = Tokenizer(num_words=vocab_size, oov_token='<OOV>')
tokenizer.fit_on_texts(X)
X_encoded = tokenizer.texts_to_sequences(X)
X_padded = pad_sequences(X_encoded, maxlen=max_len)
print(X_padded.shape)
# Out:
# (6489, 200)

# %%
# 데이터분리/텐서변환
import torch
from sklearn.model_selection import train_test_split
from torch.utils.data import TensorDataset, DataLoader

X_train, X_test, y_train, y_test = train_test_split(torch.tensor(X_padded), torch.tensor(y), test_size=0.2, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# dataset/dataloader
train_dataset = TensorDataset(X_train, y_train)
val_dataset = TensorDataset(X_val, y_val)
test_dataset = TensorDataset(X_test, y_test)

batch_size = 64
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
# 모델 생성
import torch.nn as nn

class LSTMClassifier(nn.Module):
    def __init__(self, vocab_size, embedding_dim, hidden_size):
        super().__init__()
        self.embedding = nn.Embedding(vocab_size, embedding_dim, padding_idx=0)
        self.lstm = nn.LSTM(embedding_dim, hidden_size, batch_first=True)
        self.fc = nn.Linear(hidden_size, 3)

    def forward(self, x):
        x = self.embedding(x)
        _, (h, c) = self.lstm(x)
        out = self.fc(h[-1])
        return out

# %%
# 모델 학습
import torch.optim as optim

embedding_dim = 100
hidden_size = 128

model = LSTMClassifier(vocab_size, embedding_dim, hidden_size)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# 학습루프
train_losses, train_accs = [], []
val_losses, val_accs = [], []

epochs = 50
for epoch in range(epochs):

    # 학습
    model.train()
    train_loss, train_correct, train_total = 0, 0, 0

    for X_batch, y_batch in train_loader:
        optimizer.zero_grad()
        output = model(X_batch)
        loss = criterion(output, y_batch)
        loss.backward()
        optimizer.step()

        train_loss += loss.detach().item()
        pred = output.argmax(dim=1)
        train_correct += (pred == y_batch).sum().detach().item()
        train_total += len(y_batch)

    train_loss /= len(train_loader)
    train_acc = train_correct / train_total
    train_losses.append(train_loss)
    train_accs.append(train_acc)

    # 검증
    model.eval()
    val_loss, val_correct, val_total = 0, 0, 0

    with torch.no_grad():
        for X_batch, y_batch in val_loader:
            output = model(X_batch)
            loss = criterion(output, y_batch)

            val_loss += loss.detach().item()
            pred = output.argmax(dim=1)
            val_correct += (pred == y_batch).sum().detach().item()
            val_total += len(y_batch)

        val_loss /= len(val_loader)
        val_acc = val_correct / val_total
        val_losses.append(val_loss)
        val_accs.append(val_acc)

    # 출력(train_loss, val_loss)
    print(f'Epoch {epoch + 1}/{epochs}: '
          f'Train Loss {train_loss:.4f}, '
          f'Train Acc {train_acc:.4f}, '
          f'Val Loss {val_loss:.4f}, '
          f'Val Acc {val_acc:.4f}, ')
# Out:
# Epoch 1/50: Train Loss 0.2428, Train Acc 0.9492, Val Loss 0.0235, Val Acc 0.9942,
# Epoch 2/50: Train Loss 0.0171, Train Acc 0.9961, Val Loss 0.0146, Val Acc 0.9962,
# Epoch 3/50: Train Loss 0.0111, Train Acc 0.9966, Val Loss 0.0103, Val Acc 0.9962,
# Epoch 4/50: Train Loss 0.0056, Train Acc 0.9990, Val Loss 0.0033, Val Acc 0.9990,
# Epoch 5/50: Train Loss 0.0035, Train Acc 0.9993, Val Loss 0.0019, Val Acc 1.0000,
# Epoch 6/50: Train Loss 0.0066, Train Acc 0.9981, Val Loss 0.0031, Val Acc 0.9990,
# Epoch 7/50: Train Loss 0.0083, Train Acc 0.9976, Val Loss 0.0024, Val Acc 1.0000,
# Epoch 8/50: Train Loss 0.0031, Train Acc 0.9995, Val Loss 0.0013, Val Acc 1.0000,
# Epoch 9/50: Train Loss 0.0010, Train Acc 1.0000, Val Loss 0.0008, Val Acc 1.0000,
# Epoch 10/50: Train Loss 0.0006, Train Acc 1.0000, Val Loss 0.0005, Val Acc 1.0000,
# Epoch 11/50: Train Loss 0.0004, Train Acc 1.0000, Val Loss 0.0004, Val Acc 1.0000,
# Epoch 12/50: Train Loss 0.0003, Train Acc 1.0000, Val Loss 0.0003, Val Acc 1.0000,
# Epoch 13/50: Train Loss 0.0002, Train Acc 1.0000, Val Loss 0.0002, Val Acc 1.0000,
# Epoch 14/50: Train Loss 0.0002, Train Acc 1.0000, Val Loss 0.0002, Val Acc 1.0000,
# Epoch 15/50: Train Loss 0.0001, Train Acc 1.0000, Val Loss 0.0002, Val Acc 1.0000,
# Epoch 16/50: Train Loss 0.0001, Train Acc 1.0000, Val Loss 0.0001, Val Acc 1.0000,
# Epoch 17/50: Train Loss 0.0001, Train Acc 1.0000, Val Loss 0.0001, Val Acc 1.0000,
# Epoch 18/50: Train Loss 0.0001, Train Acc 1.0000, Val Loss 0.0001, Val Acc 1.0000,
# Epoch 19/50: Train Loss 0.0001, Train Acc 1.0000, Val Loss 0.0001, Val Acc 1.0000,
# Epoch 20/50: Train Loss 0.0001, Train Acc 1.0000, Val Loss 0.0001, Val Acc 1.0000,
# Epoch 21/50: Train Loss 0.0001, Train Acc 1.0000, Val Loss 0.0001, Val Acc 1.0000,
# Epoch 22/50: Train Loss 0.0001, Train Acc 1.0000, Val Loss 0.0001, Val Acc 1.0000,
# Epoch 23/50: Train Loss 0.0001, Train Acc 1.0000, Val Loss 0.0001, Val Acc 1.0000,
# Epoch 24/50: Train Loss 0.0001, Train Acc 1.0000, Val Loss 0.0001, Val Acc 1.0000,
# Epoch 25/50: Train Loss 0.0000, Train Acc 1.0000, Val Loss 0.0001, Val Acc 1.0000,
# Epoch 26/50: Train Loss 0.0000, Train Acc 1.0000, Val Loss 0.0001, Val Acc 1.0000,
# Epoch 27/50: Train Loss 0.0000, Train Acc 1.0000, Val Loss 0.0000, Val Acc 1.0000,
# Epoch 28/50: Train Loss 0.0000, Train Acc 1.0000, Val Loss 0.0000, Val Acc 1.0000,
# Epoch 29/50: Train Loss 0.0000, Train Acc 1.0000, Val Loss 0.0000, Val Acc 1.0000,
# Epoch 30/50: Train Loss 0.0000, Train Acc 1.0000, Val Loss 0.0000, Val Acc 1.0000,
# Epoch 31/50: Train Loss 0.0000, Train Acc 1.0000, Val Loss 0.0000, Val Acc 1.0000,
# Epoch 32/50: Train Loss 0.0000, Train Acc 1.0000, Val Loss 0.0000, Val Acc 1.0000,
# Epoch 33/50: Train Loss 0.0000, Train Acc 1.0000, Val Loss 0.0000, Val Acc 1.0000,
# Epoch 34/50: Train Loss 0.0000, Train Acc 1.0000, Val Loss 0.0000, Val Acc 1.0000,
# Epoch 35/50: Train Loss 0.0000, Train Acc 1.0000, Val Loss 0.0000, Val Acc 1.0000,
# Epoch 36/50: Train Loss 0.0000, Train Acc 1.0000, Val Loss 0.0000, Val Acc 1.0000,
# Epoch 37/50: Train Loss 0.0000, Train Acc 1.0000, Val Loss 0.0000, Val Acc 1.0000,
# Epoch 38/50: Train Loss 0.0000, Train Acc 1.0000, Val Loss 0.0000, Val Acc 1.0000,
# Epoch 39/50: Train Loss 0.0000, Train Acc 1.0000, Val Loss 0.0000, Val Acc 1.0000,
# Epoch 40/50: Train Loss 0.0000, Train Acc 1.0000, Val Loss 0.0000, Val Acc 1.0000,
# Epoch 41/50: Train Loss 0.0000, Train Acc 1.0000, Val Loss 0.0000, Val Acc 1.0000,
# Epoch 42/50: Train Loss 0.0000, Train Acc 1.0000, Val Loss 0.0000, Val Acc 1.0000,
# Epoch 43/50: Train Loss 0.0000, Train Acc 1.0000, Val Loss 0.0000, Val Acc 1.0000,
# Epoch 44/50: Train Loss 0.0000, Train Acc 1.0000, Val Loss 0.0000, Val Acc 1.0000,
# Epoch 45/50: Train Loss 0.0000, Train Acc 1.0000, Val Loss 0.0000, Val Acc 1.0000,
# Epoch 46/50: Train Loss 0.0000, Train Acc 1.0000, Val Loss 0.0000, Val Acc 1.0000,
# Epoch 47/50: Train Loss 0.0000, Train Acc 1.0000, Val Loss 0.0000, Val Acc 1.0000,
# Epoch 48/50: Train Loss 0.0000, Train Acc 1.0000, Val Loss 0.0000, Val Acc 1.0000,
# Epoch 49/50: Train Loss 0.0000, Train Acc 1.0000, Val Loss 0.0000, Val Acc 1.0000,
# Epoch 50/50: Train Loss 0.0000, Train Acc 1.0000, Val Loss 0.0000, Val Acc 1.0000,

# %%
# 모델 평가
from sklearn.metrics import classification_report

model.eval()
all_preds, all_labels = [], []

with torch.no_grad():
    for X_batch, y_batch in test_loader:
        output = model(X_batch)
        loss = criterion(output, y_batch)
        pred = output.argmax(dim=1)

        all_preds.extend(pred.detach().numpy())
        all_labels.extend(y_batch.detach().numpy())

print(classification_report(all_labels, all_preds, target_names=newsgroups.target_names))
# Out:
#                     precision    recall  f1-score   support
#
#      comp.graphics       1.00      1.00      1.00       524
#          sci.space       1.00      1.00      1.00       387
# rec.sport.baseball       1.00      1.00      1.00       387
#
#           accuracy                           1.00      1298
#          macro avg       1.00      1.00      1.00      1298
#       weighted avg       1.00      1.00      1.00      1298

# %% [markdown]
# ## 사전학습된 임베딩 적용하기

# %%
from gensim.models import FastText

fasttext_model = FastText.load('ted_en_fasttext.model')
print(fasttext_model.vector_size)
# Out:
# 100

# %%
import numpy as np

embedding_dim = fasttext_model.vector_size
embedding_matrix = np.zeros((vocab_size, embedding_dim))

word_index = tokenizer.word_index # 38000
word_index = {word:index for word, index in word_index.items() if index < vocab_size}
print(len(word_index)) # 10000

for word, index in word_index.items():
    if word in fasttext_model.wv:
        embedding_matrix[index] = fasttext_model.wv[word]
# Out:
# 9999

# %%
# 모델 생성
import torch.nn as nn

class LSTMClassifier2(nn.Module):
    def __init__(self, vocab_size, embedding_dim, embedding_matrix, hidden_size):
        super().__init__()
        self.embedding = nn.Embedding(vocab_size, embedding_dim, padding_idx=0)
        self.embedding.weight.data.copy_(torch.from_numpy(embedding_matrix))
        self.embedding.weight.requires_grad = False # 사전학습된 임베딩은 추가학습 안함

        self.lstm = nn.LSTM(embedding_dim, hidden_size, batch_first=True)
        self.fc = nn.Linear(hidden_size, 3)

    def forward(self, x):
        x = self.embedding(x)
        _, (h, c) = self.lstm(x)
        out = self.fc(h[-1])
        return out

# %%
# 모델 학습
import torch.optim as optim

embedding_dim = 100
hidden_size = 128

model = LSTMClassifier2(vocab_size, embedding_dim, embedding_matrix, hidden_size)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.0001)

# 학습루프
train_losses, train_accs = [], []
val_losses, val_accs = [], []

epochs = 100
for epoch in range(epochs):

    # 학습
    model.train()
    train_loss, train_correct, train_total = 0, 0, 0

    for X_batch, y_batch in train_loader:
        optimizer.zero_grad()
        output = model(X_batch)
        loss = criterion(output, y_batch)
        loss.backward()
        optimizer.step()

        train_loss += loss.detach().item()
        pred = output.argmax(dim=1)
        train_correct += (pred == y_batch).sum().detach().item()
        train_total += len(y_batch)

    train_loss /= len(train_loader)
    train_acc = train_correct / train_total
    train_losses.append(train_loss)
    train_accs.append(train_acc)

    # 검증
    model.eval()
    val_loss, val_correct, val_total = 0, 0, 0

    with torch.no_grad():
        for X_batch, y_batch in val_loader:
            output = model(X_batch)
            loss = criterion(output, y_batch)

            val_loss += loss.detach().item()
            pred = output.argmax(dim=1)
            val_correct += (pred == y_batch).sum().detach().item()
            val_total += len(y_batch)

        val_loss /= len(val_loader)
        val_acc = val_correct / val_total
        val_losses.append(val_loss)
        val_accs.append(val_acc)

    # 출력(train_loss, val_loss)
    print(f'Epoch {epoch + 1}/{epochs}: '
          f'Train Loss {train_loss:.4f}, '
          f'Train Acc {train_acc:.4f}, '
          f'Val Loss {val_loss:.4f}, '
          f'Val Acc {val_acc:.4f}, ')
# Out:
# Epoch 1/100: Train Loss 1.0766, Train Acc 0.4564, Val Loss 1.0422, Val Acc 0.3792,
# Epoch 2/100: Train Loss 0.8575, Train Acc 0.7355, Val Loss 0.5837, Val Acc 0.9249,
# Epoch 3/100: Train Loss 0.4729, Train Acc 0.9333, Val Loss 0.3734, Val Acc 0.9394,
# Epoch 4/100: Train Loss 0.3022, Train Acc 0.9554, Val Loss 0.2402, Val Acc 0.9615,
# Epoch 5/100: Train Loss 0.2032, Train Acc 0.9711, Val Loss 0.1508, Val Acc 0.9788,
# Epoch 6/100: Train Loss 0.1394, Train Acc 0.9810, Val Loss 0.1476, Val Acc 0.9711,
# Epoch 7/100: Train Loss 0.1018, Train Acc 0.9877, Val Loss 0.0827, Val Acc 0.9856,
# Epoch 8/100: Train Loss 0.0737, Train Acc 0.9911, Val Loss 0.0598, Val Acc 0.9952,
# Epoch 9/100: Train Loss 0.0553, Train Acc 0.9928, Val Loss 0.0482, Val Acc 0.9962,
# Epoch 10/100: Train Loss 0.0442, Train Acc 0.9935, Val Loss 0.0389, Val Acc 0.9952,
# Epoch 11/100: Train Loss 0.0366, Train Acc 0.9954, Val Loss 0.0382, Val Acc 0.9933,
# Epoch 12/100: Train Loss 0.0323, Train Acc 0.9957, Val Loss 0.0314, Val Acc 0.9962,
# Epoch 13/100: Train Loss 0.0273, Train Acc 0.9957, Val Loss 0.0309, Val Acc 0.9952,
# Epoch 14/100: Train Loss 0.0245, Train Acc 0.9964, Val Loss 0.0254, Val Acc 0.9962,
# Epoch 15/100: Train Loss 0.0229, Train Acc 0.9961, Val Loss 0.0243, Val Acc 0.9942,
# Epoch 16/100: Train Loss 0.0210, Train Acc 0.9966, Val Loss 0.0235, Val Acc 0.9952,
# Epoch 17/100: Train Loss 0.0182, Train Acc 0.9966, Val Loss 0.0203, Val Acc 0.9952,
# Epoch 18/100: Train Loss 0.0161, Train Acc 0.9974, Val Loss 0.0210, Val Acc 0.9942,
# Epoch 19/100: Train Loss 0.0152, Train Acc 0.9969, Val Loss 0.0223, Val Acc 0.9923,
# Epoch 20/100: Train Loss 0.0137, Train Acc 0.9974, Val Loss 0.0214, Val Acc 0.9942,
# Epoch 21/100: Train Loss 0.0123, Train Acc 0.9976, Val Loss 0.0225, Val Acc 0.9933,
# Epoch 22/100: Train Loss 0.0286, Train Acc 0.9930, Val Loss 0.0194, Val Acc 0.9952,
# Epoch 23/100: Train Loss 0.0149, Train Acc 0.9961, Val Loss 0.0196, Val Acc 0.9952,
# Epoch 24/100: Train Loss 0.0113, Train Acc 0.9974, Val Loss 0.0192, Val Acc 0.9933,
# Epoch 25/100: Train Loss 0.0100, Train Acc 0.9976, Val Loss 0.0189, Val Acc 0.9933,
# Epoch 26/100: Train Loss 0.0098, Train Acc 0.9981, Val Loss 0.0158, Val Acc 0.9962,
# Epoch 27/100: Train Loss 0.0105, Train Acc 0.9974, Val Loss 0.0185, Val Acc 0.9952,
# Epoch 28/100: Train Loss 0.0084, Train Acc 0.9983, Val Loss 0.0151, Val Acc 0.9952,
# Epoch 29/100: Train Loss 0.0117, Train Acc 0.9974, Val Loss 0.0167, Val Acc 0.9952,
# Epoch 30/100: Train Loss 0.0115, Train Acc 0.9971, Val Loss 0.0148, Val Acc 0.9952,
# Epoch 31/100: Train Loss 0.0076, Train Acc 0.9986, Val Loss 0.0249, Val Acc 0.9933,
# Epoch 32/100: Train Loss 0.0145, Train Acc 0.9964, Val Loss 0.0171, Val Acc 0.9952,
# Epoch 33/100: Train Loss 0.0079, Train Acc 0.9986, Val Loss 0.0154, Val Acc 0.9962,
# Epoch 34/100: Train Loss 0.0064, Train Acc 0.9993, Val Loss 0.0153, Val Acc 0.9962,
# Epoch 35/100: Train Loss 0.0056, Train Acc 0.9993, Val Loss 0.0136, Val Acc 0.9962,
# Epoch 36/100: Train Loss 0.0052, Train Acc 0.9993, Val Loss 0.0136, Val Acc 0.9962,
# Epoch 37/100: Train Loss 0.0051, Train Acc 0.9993, Val Loss 0.0128, Val Acc 0.9962,
# Epoch 38/100: Train Loss 0.0047, Train Acc 0.9993, Val Loss 0.0129, Val Acc 0.9962,
# Epoch 39/100: Train Loss 0.0046, Train Acc 0.9993, Val Loss 0.0118, Val Acc 0.9962,
# Epoch 40/100: Train Loss 0.0044, Train Acc 0.9993, Val Loss 0.0111, Val Acc 0.9971,
# Epoch 41/100: Train Loss 0.0043, Train Acc 0.9990, Val Loss 0.0108, Val Acc 0.9971,
# Epoch 42/100: Train Loss 0.0040, Train Acc 0.9990, Val Loss 0.0105, Val Acc 0.9962,
# Epoch 43/100: Train Loss 0.0038, Train Acc 0.9993, Val Loss 0.0101, Val Acc 0.9962,
# Epoch 44/100: Train Loss 0.0037, Train Acc 0.9993, Val Loss 0.0095, Val Acc 0.9971,
# Epoch 45/100: Train Loss 0.0035, Train Acc 0.9990, Val Loss 0.0094, Val Acc 0.9962,
# Epoch 46/100: Train Loss 0.0034, Train Acc 0.9993, Val Loss 0.0090, Val Acc 0.9971,
# Epoch 47/100: Train Loss 0.0032, Train Acc 0.9995, Val Loss 0.0086, Val Acc 0.9971,
# Epoch 48/100: Train Loss 0.0032, Train Acc 0.9995, Val Loss 0.0078, Val Acc 0.9971,
# Epoch 49/100: Train Loss 0.0031, Train Acc 0.9995, Val Loss 0.0074, Val Acc 0.9971,
# Epoch 50/100: Train Loss 0.0028, Train Acc 0.9995, Val Loss 0.0104, Val Acc 0.9952,
# Epoch 51/100: Train Loss 0.0027, Train Acc 0.9995, Val Loss 0.0075, Val Acc 0.9962,
# Epoch 52/100: Train Loss 0.0026, Train Acc 0.9995, Val Loss 0.0063, Val Acc 0.9971,
# Epoch 53/100: Train Loss 0.0025, Train Acc 0.9995, Val Loss 0.0071, Val Acc 0.9962,
# Epoch 54/100: Train Loss 0.0023, Train Acc 0.9995, Val Loss 0.0059, Val Acc 0.9971,
# Epoch 55/100: Train Loss 0.0161, Train Acc 0.9971, Val Loss 0.0104, Val Acc 0.9971,
# Epoch 56/100: Train Loss 0.0139, Train Acc 0.9974, Val Loss 0.0097, Val Acc 0.9971,
# Epoch 57/100: Train Loss 0.0079, Train Acc 0.9983, Val Loss 0.0089, Val Acc 0.9971,
# Epoch 58/100: Train Loss 0.0103, Train Acc 0.9976, Val Loss 0.0082, Val Acc 0.9971,
# Epoch 59/100: Train Loss 0.0045, Train Acc 0.9990, Val Loss 0.0077, Val Acc 0.9971,
# Epoch 60/100: Train Loss 0.0079, Train Acc 0.9978, Val Loss 0.0068, Val Acc 0.9971,
# Epoch 61/100: Train Loss 0.0034, Train Acc 0.9990, Val Loss 0.0068, Val Acc 0.9971,
# Epoch 62/100: Train Loss 0.0027, Train Acc 0.9993, Val Loss 0.0055, Val Acc 0.9971,
# Epoch 63/100: Train Loss 0.0022, Train Acc 0.9995, Val Loss 0.0054, Val Acc 0.9971,
# Epoch 64/100: Train Loss 0.0020, Train Acc 0.9995, Val Loss 0.0045, Val Acc 0.9971,
# Epoch 65/100: Train Loss 0.0018, Train Acc 0.9998, Val Loss 0.0041, Val Acc 0.9981,
# Epoch 66/100: Train Loss 0.0016, Train Acc 0.9998, Val Loss 0.0036, Val Acc 0.9990,
# Epoch 67/100: Train Loss 0.0015, Train Acc 0.9998, Val Loss 0.0035, Val Acc 0.9981,
# Epoch 68/100: Train Loss 0.0013, Train Acc 1.0000, Val Loss 0.0028, Val Acc 0.9990,
# Epoch 69/100: Train Loss 0.0012, Train Acc 1.0000, Val Loss 0.0027, Val Acc 0.9990,
# Epoch 70/100: Train Loss 0.0011, Train Acc 1.0000, Val Loss 0.0026, Val Acc 0.9990,
# Epoch 71/100: Train Loss 0.0010, Train Acc 1.0000, Val Loss 0.0031, Val Acc 0.9990,
# Epoch 72/100: Train Loss 0.0009, Train Acc 1.0000, Val Loss 0.0022, Val Acc 0.9990,
# Epoch 73/100: Train Loss 0.0009, Train Acc 1.0000, Val Loss 0.0020, Val Acc 0.9990,
# Epoch 74/100: Train Loss 0.0008, Train Acc 1.0000, Val Loss 0.0021, Val Acc 0.9990,
# Epoch 75/100: Train Loss 0.0008, Train Acc 1.0000, Val Loss 0.0017, Val Acc 0.9990,
# Epoch 76/100: Train Loss 0.0007, Train Acc 1.0000, Val Loss 0.0019, Val Acc 0.9990,
# Epoch 77/100: Train Loss 0.0007, Train Acc 1.0000, Val Loss 0.0016, Val Acc 1.0000,
# Epoch 78/100: Train Loss 0.0006, Train Acc 1.0000, Val Loss 0.0015, Val Acc 1.0000,
# Epoch 79/100: Train Loss 0.0006, Train Acc 1.0000, Val Loss 0.0015, Val Acc 1.0000,
# Epoch 80/100: Train Loss 0.0006, Train Acc 1.0000, Val Loss 0.0015, Val Acc 1.0000,
# Epoch 81/100: Train Loss 0.0005, Train Acc 1.0000, Val Loss 0.0014, Val Acc 0.9990,
# Epoch 82/100: Train Loss 0.0005, Train Acc 1.0000, Val Loss 0.0012, Val Acc 1.0000,
# Epoch 83/100: Train Loss 0.0005, Train Acc 1.0000, Val Loss 0.0011, Val Acc 1.0000,
# Epoch 84/100: Train Loss 0.0004, Train Acc 1.0000, Val Loss 0.0011, Val Acc 1.0000,
# Epoch 85/100: Train Loss 0.0004, Train Acc 1.0000, Val Loss 0.0009, Val Acc 1.0000,
# Epoch 86/100: Train Loss 0.0004, Train Acc 1.0000, Val Loss 0.0010, Val Acc 1.0000,
# Epoch 87/100: Train Loss 0.0004, Train Acc 1.0000, Val Loss 0.0009, Val Acc 1.0000,
# Epoch 88/100: Train Loss 0.0003, Train Acc 1.0000, Val Loss 0.0010, Val Acc 1.0000,
# Epoch 89/100: Train Loss 0.0003, Train Acc 1.0000, Val Loss 0.0008, Val Acc 1.0000,
# Epoch 90/100: Train Loss 0.0003, Train Acc 1.0000, Val Loss 0.0008, Val Acc 1.0000,
# Epoch 91/100: Train Loss 0.0003, Train Acc 1.0000, Val Loss 0.0007, Val Acc 1.0000,
# Epoch 92/100: Train Loss 0.0003, Train Acc 1.0000, Val Loss 0.0008, Val Acc 1.0000,
# Epoch 93/100: Train Loss 0.0003, Train Acc 1.0000, Val Loss 0.0006, Val Acc 1.0000,
# Epoch 94/100: Train Loss 0.0002, Train Acc 1.0000, Val Loss 0.0008, Val Acc 1.0000,
# Epoch 95/100: Train Loss 0.0002, Train Acc 1.0000, Val Loss 0.0008, Val Acc 1.0000,
# Epoch 96/100: Train Loss 0.0002, Train Acc 1.0000, Val Loss 0.0005, Val Acc 1.0000,
# Epoch 97/100: Train Loss 0.0002, Train Acc 1.0000, Val Loss 0.0006, Val Acc 1.0000,
# Epoch 98/100: Train Loss 0.0002, Train Acc 1.0000, Val Loss 0.0004, Val Acc 1.0000,
# Epoch 99/100: Train Loss 0.0002, Train Acc 1.0000, Val Loss 0.0005, Val Acc 1.0000,
# Epoch 100/100: Train Loss 0.0002, Train Acc 1.0000, Val Loss 0.0004, Val Acc 1.0000,

# %%
# 모델 평가
from sklearn.metrics import classification_report

model.eval()
all_preds, all_labels = [], []

with torch.no_grad():
    for X_batch, y_batch in test_loader:
        output = model(X_batch)
        loss = criterion(output, y_batch)
        pred = output.argmax(dim=1)

        all_preds.extend(pred.detach().numpy())
        all_labels.extend(y_batch.detach().numpy())

print(classification_report(all_labels, all_preds, target_names=newsgroups.target_names))
# Out:
#                     precision    recall  f1-score   support
#
#      comp.graphics       1.00      1.00      1.00       524
#          sci.space       1.00      1.00      1.00       387
# rec.sport.baseball       1.00      1.00      1.00       387
#
#           accuracy                           1.00      1298
#          macro avg       1.00      1.00      1.00      1298
#       weighted avg       1.00      1.00      1.00      1298
